# %% [markdown]
# <figure>
# <IMG SRC="../../lectures/images/PhysicsLogo.jpg" WIDTH=100 ALIGN="right">
# </figure>
# # [Physics 411](http://jklymak.github.io/Phy411/) Time Series Analysis
# *Jody Klymak*

# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Q1: Simulate aliasing of sinusoidal signals
#
# For this problem you will simulate the phenomena of aliasing.  This will give you pracitice in making synthetic time series, subsetting data, and plotting your results.
#
# **1** To start, make a time vector that goes from 0 to 120 s, with 10000 entries in it.  Then make a synthetic time series that has two close in frequency sine waves:
#
# $$ x = A_1 \cos (\omega t) + A_2 \cos ((\omega_1+\delta \omega ) t) $$
#
# where $\omega$ is the "carrier" frequency, and $\delta \omega << \omega$ is the difference in frequencies between the two waves.  For simplicty, you could make $A_1=A_2=1. [V]$.  Feel free to choose an interesting $\omega$.
#
# <hr>

# %%
# You will almost always need to import these:  Make sure to run this cell!
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import math as math
t= np.linspace(0, 120, 10000) # time vector
w= math.pi/3
dw= math.pi/18
x1= np.cos(w*t)
x2= np.cos((w+dw)*t)
x=x1+x2 # the synthetic time series

# %% [markdown]
# **2** Now plot the two component waves and the full value of $x$ as a time series.  Preferably on the same axis.  Make sure to label your axes and include a legend<hr>

# %%
def makePlot(t, x1, x2, x, w=math.pi/3, dw=math.pi/36): 
    x2= np.cos((w+dw)*t)
    x=x1+x2
    fig= plt.figure(figsize=(7, 4))

    print fig
    axes= fig.add_subplot(1, 1, 1)
    axes.plot(t, x1, label='$x_1,  \omega_1=%1.2f$'%(w))
    axes.plot(t, x2, label= '$x_2,  \omega_2=\omega_1+\delta\omega,  \delta\omega=%1.2f$ '%(dw))
    axes.plot(t, x, label= '$x=x_1+x_2$')
    axes.set_xlabel('Time [s]')
    axes.set_ylabel('Amplitude[m]')
    axes.legend(loc=0)
    
makePlot(t, x1, x2, x)
# Out:
# Figure(560x320)

# %% [markdown]
# **3** Try a few different values of $\delta\omega$, and compare.<hr>

# %%
makePlot(t, x1, x2, x, w, dw=math.pi/54)

makePlot(t, x1, x2, x, w, dw=math.pi/24)
# Out:
# Figure(560x320)
# Figure(560x320)

# %% [markdown]
# **4** Now, just so this works, let me specify some numbers for you.  Make $\omega=\frac{2\pi}{3}$, and $\delta\omega=\omega/10.$.  Plot the original time series, and a subsampled time series that just consists of every 200th point.  In a "Markdown" box below the code (or as a comment) describe the difference in these two signals as quantifiably as you can.  <hr>

# %%
w= 2*math.pi/3
x1= np.cos(w*t)
makePlot(t, x1, x2, x,w=(2*math.pi/3), dw=(w/10))
dw=w/10
x2= np.cos((w+dw)*t)
x=x1+x2

newx1=x1[0::200]
newx2=x2[0::200]
newx=newx1+newx2
newt=t[0::200]

fig= plt.figure(figsize=(7, 4))
ax=fig.add_subplot(1,1,1)
ax.plot(newt, newx1, label='$x_1$')
ax.plot(newt, newx2, label='$x_2$')
ax.plot(newt, newx, label='$x$')
ax.set_xlabel('time (s)')
ax.set_ylabel('Amplitude (m)')
ax.set_title('Subsampled Time Series- every 200th pt')
ax.legend(loc=0)
print fig
# Out:
# Figure(560x320)
# Figure(560x320)

# %% [markdown]
# What is the difference in these two signals?
# Quantifiably, the first graph with all the points gives much more detail of what is going on, and you can see a clear picture of the size of the wavelength. In the second, subsmpled graph, there is so little data that one may think the wavelength is very large, as instead of about two seconds from one peak to the next( like the first graph) there appears to be about twenty seconds between peaks in the bottom graph, and the true signal is not represented very well at all.

# %% [markdown]
# ## Q2: Demonstrate the central limit theorem for a very unfair coin flip.

# %% [markdown]
# Consider a coin that is twice as likely to come up heads as tails. To put a number on it, call tails $x=-1/2$ and heads $x=+1/2$.
#
# **1** What are the mean, $\mu_x$, and variance $\sigma_x^2$ of this process?
#
# <hr>

# %% [markdown]
# YOUR ANSWER HERE

# %%
x1= -1.0/2 #for tails, p(x1)= 1/3
x2= 1.0/2  #for heads, p(x2)= 2/3

# mean = mu =summation from i=1 to 2 of  ( p(xi)*xi)
#           = p(x1)*(x1)+p(x2)*x2
mean=((1.0/3.0)*(-1.0/2.0)+(2.0/3.0)*(1.0/2.0))
print 'The mean is:%1.3f'%(mean)

#var= sigma^2= sum from i=1 to 2 of ( p(xi)*(xi-mu_x)^2)
#            = p(x1)*(x1-mean)^2+ p(x2)*(x2-mean)^2
var=(math.pow((-.5-1.0/6), 2)*(1.0/3))+(math.pow((.5-1.0/6),2)*2.0/3)
print 'The varience is:%1.3f'%(var)
# Out:
# The mean is:0.167
# The varience is:0.222

# %% [markdown]
# **2** Plot or represent the *probability distribution*  (or cumulative distrubution) of this process.
# <hr>

# %%
prob=np.array([0, 1, 2, 0])
x = np.arange(-1.5,1.5,0.01)
P = x*0.
val=0
for i in range(0,3):
    val=i-1.5
    if val==(-1.0/2):
        P[x>val]=1./3
    elif val==.5:
        P[x>val]=1
fig=plt.figure(figsize=(3,4))
print fig
ax=fig.add_subplot(1,1,1)
ax.plot(x, P, label='Probablility Distribution')
ax.set_xlabel('x- Coin Flip')
ax.set_ylabel('P(x)')
ax.legend(loc=0)
ax.set_ylim([-.2,1.1])
# Out:
# Figure(240x320)
# (-0.2, 1.1)

# %% [markdown]
# **3** Write a function using the `np.random.rand` function to simulate the coin flip.  It shoudl return $+1/2+$ twice as often as $-1/2$.  Demonstrate that your function works.
# <hr>

# %%
def coinFlip(N, doprint=False, seed= None):
    roll= np.random.rand(N)
    numT=0
    numH=0
    for i in range(0,N,1):
        if roll[i]<=(1.0/3):
            roll[i]= -1.0/2
            numT+=1
        else:
            roll[i]=1./2
            numH+=1
    if doprint==True:
        perH= float(numH)/N
        perT= float(numT)/N
        print 'Number of rolls: %d' %N
        print 'Number of tails: %d' %numT
        print '     with a percent of %1.2f'%perT
        print 'Number of heads: %d' %numH
        print '     with a percent of %1.2f'%perH
    return roll 
roll= coinFlip(200, doprint=True)
# Out:
# Number of rolls: 200
# Number of tails: 67
#      with a percent of 0.34
# Number of heads: 133
#      with a percent of 0.67

# %% [markdown]
# **4** Perform $N_{flip}$ and take the sample mean $\overline{x}$ of the values.  Do this 2000 times, and show that as $N_{flip}\to\infty$ the distribution of $\overline{x}$ approaches a Normal distribution by plotting the histograms of the means for each.  For $N_{flip}$ choose 2, 16, 64, 256.
#
# Comment on how the convergence of $\overline{x}$ for the unfair coin compares to the convergence of the sample mean of the dice roll from the notes.
# <hr>

# %%
import scipy.stats as stats
def twoThFlips(NFlip):
    arr= np.zeros(2000)
    for i in range (0,2000,1):
        flips=coinFlip(NFlip)
        arr[i]=np.mean(flips)
    return arr

meanFlips1= twoThFlips(NFlip=2)
fig=plt.figure(figsize=(8, 8))

ax=fig.add_subplot(221)
ax.hist(meanFlips1, normed=True)
ax.set_xlabel('$\overline{x}\ \ N=2$')
ax.set_ylabel('Occurences')
print 'N=2:   Mean of the means: %1.3f' %np.mean(meanFlips1)
print '       Standard deviation of the means: %1.3f' %np.std(meanFlips1)

meanFlips2= twoThFlips(16)
ax2=fig.add_subplot(222)
ax2.hist(meanFlips2,normed=True)
ax2.set_xlabel('$\overline{x}\ \ N=16$')
ax2.set_ylabel('Occurences')
#ax2.set_xlim([-1.0, 1.0])
print 'N=16:   Mean of the means: %1.3f' %np.mean(meanFlips2)
print '        Standard deviation of the means: %1.3f' %np.std(meanFlips2)

meanFlips3=twoThFlips(64)
ax3=fig.add_subplot(223)
ax3.hist(meanFlips3, normed= True)
ax3.set_xlabel('$\overline{x}\ \ N=64$')
ax3.set_ylabel('Occurences')
print 'N=64:   Mean of the means: %1.3f' %np.mean(meanFlips3)
print '        Standard deviation of the means: %1.3f' %np.std(meanFlips3)

meanFlips4= twoThFlips(256)
ax4=fig.add_subplot(224)
ax4.hist(meanFlips4, normed=True)
ax4.set_xlabel('$\overline{x}\ \ N=256$')
ax4.set_ylabel('Occurences')
print 'N=256:   Mean of the means: %1.3f' %np.mean(meanFlips4)
print '         Standard deviation of the means: %1.3f' %np.std(meanFlips4)

print ' We can see that as N increases, the distribution of x-bar approaches a normal distrubution,'
print '  though skewed a bit to the right. '
# Out:
# N=2:   Mean of the means: 0.165
#        Standard deviation of the means: 0.337
# N=16:   Mean of the means: 0.169
#         Standard deviation of the means: 0.118
# N=64:   Mean of the means: 0.167
#         Standard deviation of the means: 0.059
# N=256:   Mean of the means: 0.167
#          Standard deviation of the means: 0.030
#  We can see that as N increases, the distribution of x-bar approaches a normal distrubution,
#   though skewed a bit to the right.

# %% [markdown]
# For the unfair coin toss, $\overline{x}$ seems to converge faster than for the dice the notes. After flipping the coin 256 times 2000 times, the standard deviation of the means is 0.029, whereas in the case of the coin, rolling the die 200 times 2000 times had a standard deviation of the means of 0.121.

# %% [markdown]
# <hr>
# **5** Replot the histograms, removing the mean and normalizing by the standard deviation.  Also show the CDF for normal distribution with mean zero and standard deviation of 1.
# <hr>

# %%
import matplotlib.mlab as mlab

fig=plt.figure(figsize=(8, 8))

ax=fig.add_subplot(221)
n, bins, patches= ax.hist((meanFlips1-np.mean(meanFlips1))/np.std(meanFlips1), 50, normed=True, alpha=0.75)
bincenters= 0.5*(bins[1:]+bins[:-1])
y= mlab.normpdf(bincenters, 0, 1)
l= ax.plot(bincenters, y, 'r--', linewidth=2)
ax.set_xlabel('$\overline{x}\ \ N=2$')
ax.set_ylabel('Occurences/bin')


ax2= fig.add_subplot(222)
n, bins, patches = ax2.hist((meanFlips2-np.mean(meanFlips2))/np.std(meanFlips2), 50, normed=True)
bincenters= 0.5*(bins[1:]+bins[:-1])
y= mlab.normpdf(bincenters, 0, 1)
l= ax2.plot(bincenters, y, 'r--', linewidth=2)
ax2.set_xlabel('$\overline{x}\ \ N=16$')
ax2.set_ylabel('Occurences/bin')


ax3= fig.add_subplot(223)
n, bins, patches = ax3.hist((meanFlips3-np.mean(meanFlips3))/np.std(meanFlips3), 50, normed= True)
y= mlab.normpdf(bincenters,0,1)
l= ax3.plot(bincenters,y,'r--', linewidth=2)
ax3.set_xlabel('$\overline{x}\ \ N=64$')
ax3.set_ylabel('Occurences/bin')

ax4= fig.add_subplot(224)
n, bins, patches= ax4.hist((meanFlips4-np.mean(meanFlips4))/np.std(meanFlips4),50, normed=True)
y= mlab.normpdf(bincenters,0,1)
l= ax4.plot(bincenters,y,'r--', linewidth=2)
ax4.set_xlabel('$\overline{x}\ \ N=256$')
ax4.set_ylabel('Occurences/bin')

# %%
print 'Another way to normalized the plots: '
fig=plt.figure(figsize=(10,6))
w=np.ones_like(meanFlips1)/float(len(meanFlips1))
plt.hist(meanFlips1,weights=w,label='N=2' )
plt.title('Normalized Data for the Coin Flip')

fig=plt.figure
w=np.ones_like(meanFlips2)/float(len(meanFlips2))
plt.hist(meanFlips2,weights=w, label='N=16')

fig=plt.figure
w=np.ones_like(meanFlips3)/float(len(meanFlips3))
plt.hist(meanFlips3,weights=w, label='N=64')

fig=plt.figure
w=np.ones_like(meanFlips4)/float(len(meanFlips4))
plt.hist(meanFlips4,weights=w, label='N=256')
plt.legend(loc=0)

midbins=bins[0:-1]-np.diff(bins)[0]
y = mlab.normpdf(midbins, 0, 1.)
plt.plot(midbins,y,'r--',label='Normal Dist')
plt.legend()
# Out:
# Another way to normalized the plots:

# %% [markdown]
# ## Q3: Look at the Deep Cove weather data:

# %% [markdown]
# There are two data sets, one with a sample every minute at
#
# `http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/DeepCoveNew.txt`.
#
# Download it locally, or use `genfromtxt` with the url as an argument.
#
# The second is hourly data of the smae station and a lot more.
#
# `http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/AllHourly.txt`

# %%
minutedata=np.genfromtxt('http://web.uvic.ca/~jklymak/Phy411/Data/MinuteData/DeepCoveNew.txt')[:,1]
hourdata=np.genfromtxt('http://web.uvic.ca/~jklymak/phy411/data/AllHourly.txt')[6,2:]

# %% [markdown]
# **1** Compare the normalized histograms of the two time series.  Also calculate the means and the standard deviations.
# <hr>

# %%
minutedata= minutedata[~np.isnan(minutedata)]
hourdata= hourdata[~np.isnan(hourdata)]
fig=plt.figure(figsize=(10, 10))

ax=fig.add_subplot(221)
ax.hist(minutedata)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances')
ax.set_title('Minute Data(unnormalized)')
print 'Minute Data: Mean: %1.3f' %np.mean(minutedata)
print '             Standard deviation: %1.3f' %np.std(minutedata)

ax=fig.add_subplot(222)
ax.hist(hourdata)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances')
ax.set_title('Hourly Data(unnormalized)')
print 'Hourly Data: Mean: %1.3f' %np.mean(hourdata)
print '             Standard deviation: %1.3f' %np.std(hourdata)

ax=fig.add_subplot(223)
ax.hist(((minutedata-np.mean(minutedata))/np.std(minutedata)),100, normed=True)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances/bin')
ax.set_title('Minute Data(normalized)')

ax=fig.add_subplot(224)
ax.hist(((hourdata-np.mean(hourdata))/np.std(hourdata)),100,normed=True)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances/bin')
ax.set_title('Hourly Data(normalized)')
# Out:
# Minute Data: Mean: 10.302
#              Standard deviation: 5.985
# Hourly Data: Mean: 10.339
#              Standard deviation: 6.068

# %% [markdown]
# **2** Comment on the shape of these histograms.  Are they Normal?  Speculate as to why they have this shape.
# <hr>

# %% [markdown]
# The shape of the histograms is somewhat uneven, or skewed. There also appears to be two peaks, which makes them appear not normal, especially because at colder temperatures, the peak is higher. This could be because the temperature is more often less that 12 degrees, as temperatures like this occur not only on winter days and nights, but also the nights in summer. But why there is such a large dip around 12 degrees I don't know.

# %% [markdown]
# <hr>
# **3** Redo the histogram and the statistics with just the temperature at 3 PM (both time series start at midnight local time).
# <hr>

# %%
#make new array with only 3pm data: for minute data: 
#                   3pm=15:00, therefore starting at 15*60=900, then every 24*60=1440 entries
min3pmdata=minutedata[900::1440]
#                                   for hour data:
#                   3pm=15:00, start at 15, go to every 24 
hour3pmdata=hourdata[15::24]

fig=plt.figure(figsize=(10, 10))

ax=fig.add_subplot(221)
ax.hist(min3pmdata)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances')
ax.set_title('3pm Data from Minute Data(unnormalized)')
print '3pm Minute Data: Mean: %1.3f' %np.mean(min3pmdata)
print '             Standard deviation: %1.3f' %np.std(min3pmdata)

ax=fig.add_subplot(222)
ax.hist(hour3pmdata)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances')
ax.set_title('3pm data from Hourly Data(unnormalized)')
print '3pm Hourly Data: Mean: %1.3f' %np.mean(hour3pmdata)
print '             Standard deviation: %1.3f' %np.std(hour3pmdata)

ax=fig.add_subplot(223)
ax.hist((min3pmdata-np.mean(min3pmdata))/np.std(min3pmdata),100)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances/bin')
ax.set_title('3pm Data from Minute Data(normalized)')

ax=fig.add_subplot(224)
ax.hist((hour3pmdata-np.mean(hour3pmdata))/np.std(hour3pmdata),100)
ax.set_xlabel('Temperature(degrees C)')
ax.set_ylabel('Occurances/bin')
ax.set_title('3pm Data from Hourly Data(normalized)')
# Out:
# 3pm Minute Data: Mean: 8.639
#              Standard deviation: 4.449
# 3pm Hourly Data: Mean: 11.090
#              Standard deviation: 6.302

# %% [markdown]
# **4** Redo the histogram and the statistics with just the temperature at 5 AM (both time series start at midnight local time).

# %%
#now make new array with only data from 5am
min5amdata=minutedata[300::1440]
hour5amdata=hourdata[5::24]
fig=plt.figure(figsize=(10,10))

print 'for minute data at 5AM:  Mean: %1.3f' %np.mean(min5amdata)
print '                         Standard Deviation: %1.3f' %np.std(min5amdata)
print 'for hourly dataat 5AM:   Mean: %1.3f' %np.mean(hour5amdata)
print '                         Standard Deviation: %1.3f' %np.std(hour5amdata)

ax=fig.add_subplot(221)
ax.hist(min5amdata)
ax.set_xlabel('Temperature(degrees C)')
ax.set_ylabel('Occurances')
ax.set_title('5 AM Data from Min Data(unnormalized)')


ax=fig.add_subplot(222)
ax.hist(hour5amdata)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances')
ax.set_title('5 AM Data from Hour Data(unnormalized)')

ax=fig.add_subplot(223)
ax.hist((min5amdata-np.mean(min5amdata))/np.std(min5amdata),100)
ax.set_xlabel('Temperature (degrees C)')
ax.set_ylabel('Occurances/bin')
ax.set_title('5 AM Data from Minute Data(normalized)')

ax=fig.add_subplot(224)
ax.hist((hour5amdata-np.mean(hour5amdata))/np.std(hour5amdata),100)
ax.set_xlabel('Temperature(degrees C)')
ax.set_ylabel('Occurances/bin')
ax.set_title('5 AM Data from Hourly Data(normalized)')
# Out:
# for minute data at 5AM:  Mean: 10.618
#                          Standard Deviation: 6.569
# for hourly dataat 5AM:   Mean: 10.008
#                          Standard Deviation: 5.991
